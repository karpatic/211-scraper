# %% [markdown]
# R:\BNIA\VitalSigns\Vital_Signs_18\P for Pandemic\Data Libraries\BaltimoreCircuitCourt\META

# %% [markdown]
# # Intro

# %% [markdown]
# Inro
#
# CLI CLIARGS >
# MAIN>
# SPIDER > MINER > CLEANER

# %% [markdown]
# __Please note__:
# A CloseCrawl CLI exists, works, and is shown at the bottom.
# This notebook was created to troubleshoot bugs in the existing close crawlers CLI's modules. It may be used in replacement of the CLI all the same. The tab labeled "Manually Mine" is a convenience block made to execute pre-crawled pages and does not belong as part of the CLI package.

# %% [markdown]
# # Background & Resources

# %% [markdown]
# [MD Access to Judicial Records](https://govt.westlaw.com/mdc/Browse/Home/Maryland/MarylandCodeCourtRules?guid=NDF9067D03C9711E6B2B6BCAD65966614&originationContext=documenttoc&transitionType=Default&contextData=(sc.Default) )
#
# mdcourts
# - [FAQ](https://mdcourts.gov/casesearch2/faq)
# - [Terms & Disclaimer](https://mdcourts.gov/reference/termsdisclaimer)
# - [Estate Search Glossary](https://mdcourts.gov/casesearch2/estatesearchglossary)

# %% [markdown]
# Other Helpful search tips:
#
# http://www.registers.state.md.us. EstateSearch provides public Internet access to information from estate records maintained by the Maryland Registers of Wills. This information includes decedent’s name, estate number and status, date of death, date of filing, personal representative, attorney, decedent alias, and docket history. All records are available from 1998 to present for all estates filed with the Register of Wills’ office. The data is updated daily at the end of the business day.
#
# Use a % as a wildcard when searching in a field (Smith%) would give you all names that start with Smith, Smithson, Smithsburg, Smithman, etc.
# When searching for a date range you need to enter a last name or first name (partials allowed)
# You can sort the columns by clicking on the column header.
# Click the Search again option to take you back to your previous search criteria.
# Use the clear button to clear all fields and begin your search again.
#
# List of Estate Types
#
# - Regular Estate (RE) - Assets subject to administration in excess of $30,000 ($50,000 if the spouse is the sole legatee or heir).
# - Regular Estate Judicial (RJ) - A proceeding conducted by the Orphans' Court when matters cannot be handled administratively. For example, when the validity of the will is at issue, or the will is lost, stolen or damaged.
# - Small Estate (SE) - Assets subject to administration valued at $30,000 or less ($50,000 if the spouse is the sole legatee or heir).
# -Small Estate Judicial (SJ) - A proceeding conducted by the Orphans' Court when matters cannot be handled administratively. For example, when the validity of the will is at issue, or the will is lost, stolen or damaged.
# - Foreign Proceeding (FP) - Decedent domiciled out of state with real property in Maryland.
# - Motor Vehicle (MV) - Transfer of motor vehicle only.
# - NonProbate (NP) - Property of the decedent which passes by operation of law such as a joint tenancy, tenants by the entireties, or property passing under a deed or trust, revocable or irrevocable. Non probate property must be reported to the Register of Wills on the Information Report or Application to Fix Inheritance Tax on Non-Probate assets.
# - Unprobated Will Only (UN) - Will and Information Report filed with will and/or Application to Fix Inheritance Tax.
# - Modified Administration (MA) - A procedure available when the residual legatees consists of the personal representative, spouse; and children. Estate is solvent, Final Distribution can occur within 12 months from date of appointment. A verified final report is filed within 10 months from the date of appointment.
# - Guardianship Estate (GE) - Guardianship of property for a minor.
# - Limited Order (LO) – A limited order to locate assets or a will.

# %% [markdown]
# # README
# ## Instructions for how to obtain forclosue data using foreclosue data with web scraper

# %% [markdown]
# Instructions for obtaining foreclosure case data from MD Case Search with Web Scraper: (These instructions are for the scraper designed in 2017 forward)
# ________________________________________________________________________
#
# Go to GitHub and download the files to have the web scraper installed on your desktop (or you can run it directly from GitHub) https://github.com/BNIA/Close-Crawl
#
# The usage interface is described here: https://github.com/BNIA/Close-Crawl/blob/master/docs/cli/README.md
#
# 1. Enter Case type: C for tax sale foreclosures, O for mortgage foreclosures
# 2. Enter year: (Year must be 4 digits)
# 3. Enter name of output file name (must be csv file path, this will be saved onto your desktop)
# 4. Enter 0 for manual parameters or 1 for automatic (0 is recommended)
# 5. Enter the lower bound for the cases to scrape (1-4 digit integer).
#         A. If you are scraping cases from a year for the first time that year, you will want to start with "1".
#         B. In all other scenarios you need to go look at the last data scraped in the raw folder of that dataset. Look at the case number for the last case that was scraped,              look at the last for digits and go up by one number. For example, if the last case scraped was case number 24O17002002, you will want to make the lower bound 2003.
# 6. Enter the upper bound (1-4 digit integer): It is recommended to not try to scrape too many at a time, this sometimes results in errors. Scrape about 1500 at a time. The        upper bound should be about 1500 higher a number than your lower bound.
# 	A. Sometimes it is difficult to know how far to scrape because you don't know how many total cases there are for a given year. One suggestion is to look at the                    dates of the cases you have scrapped. If you have scrapped cases up to December 30 of that year than you have scraped all of the cases. To be safe put in a higher              upper bound than the last cases for December and if nothing comes back then you will know you got them all. This can be a bit of trial and error because there may              be big gaps in the case numbers for the foreclosure cases we want to scrape.
# 7. Enter 1 for debug.
# 8. Enter 1 for scrape.
# 9. Enter 1 for mine.
# 10. Enter 1 for clean.
#
#
# Save completed file in the appropriate folder for raw data- make sure mortgage foreclosure data is saved with mortgage data and tax with tax. There will be additional files that are saved to your desktop during the scraping process. These can be moved to the trash after the raw file is saved.
#
# *NOTE: If you are scraping a lot of data be sure to make each file pathway a unique name, saving multiple scraping sessions as the same csv name will cause errors.

# %% [markdown]
# # Setup

# %%
# %%capture
! pip install mechanicalsoup
! pip install urlopen

# %%
import mechanicalsoup
mechanicalsoup.__version__
# Out:
# '0.12.0'

# %%
ls
# Out:
# sample_data/

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
cd 'My Drive'/colabs/vitalSigns/close_crawl
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl

# %%
ls
# Out:
#  checkpoint.json  'Close Crawl.ipynb'   output.csv     temp_data.csv
#  cliargs.py        modules/             __pycache__/   _version.py
#  cli.py            no_case.json         responses/

# %%
# For relative imports to work in Python 3.6
import os, sys; 
os.path.realpath('./')
# Out:
# '/gdrive/My Drive/colabs/vitalSigns/close_crawl'

# %%
# To Import Local Libraries, Append the current path to the System Library
sys.path.append(os.path.dirname(os.path.realpath('/gdrive/My Drive/colabs/vitalSigns/close_crawl/modules/settings.py')))
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/gdrive/My Drive/colabs/vitalSigns/close_crawl/modules']

# %% [markdown]
# # Scrape

# %% [markdown]
# ### Local Browser

# %%
localBrowserLbl = """local_browser

  NOTICE: Close Crawl runs its browser form submissions through Mechanize.
  The module, however, is deprecated and does not support Python 3. The more
  stable and maintained Mechanize and BeautifulSoup wrapper, MechanicalSoup,
  will be replacing the Mechanize methods to support Python 3.

  This module contains the configurations and settings for the browser used for
  crawling and scraping through the pages in Close Crawl. The script contains the
  implementation of the Session class which inherits attributes from the classobj
  mechanize.Browser()

  The script works as an internal module for Close Crawl, but can be imported
  as a module for testing purposes.
  """

# %%
from __future__ import absolute_import, print_function, unicode_literals
import http.cookiejar as cookielib # for Python3
import warnings
from urllib.request import urlopen
import mechanicalsoup
from settings import HEADER, URL
warnings.filterwarnings("ignore", category=UserWarning)

# %%
class Session(object):

    def __init__(self):
        """ Constructor
        Attributes: browser (`mechanize._mechanize.Browser`): browser object in session
        """ 
        # set error and debug handlers for the browser 
        self.browser = mechanicalsoup.StatefulBrowser() 
        self.browser.set_cookiejar(cookielib.LWPCookieJar()) 

    def close(self): 
      """Closes current browser session """ 
      self.browser.close()

    def case_id_form(self, case):
        """Grabs the form in the case searching page, and inputs the
        case number to return the response. 
        Args: case (`str`): case ID to be scraped 
        Returns: response (`str`): HTML response
        """ 
        self.browser.select_form('form[action="/casesearch/inquiryByCaseNum.jis"]') 

        # Submit case ID and get back case information
        self.browser["caseId"] = case
        response = self.browser.submit_selected()
        response = response.text
        self.browser.open("http://casesearch.courts.state.md.us/casesearch/inquiryByCaseNum.jis")

        # Return only Foreclosures
        return response if any(
            case_type in response.upper() for case_type in
            ("FORECLOSURE", "FORECLOSURE RIGHTS OF REDEMPTION")
        ) else False

    def disclaimer_form(self):
        """Navigates to the URL to proceed to the case searching page """
        # visit the site
        print(URL)
        self.browser.open("http://casesearch.courts.state.md.us/casesearch/")

        # select the only form on the page
        self.browser.select_form('form')

        # select the checkbox
        self.browser["disclaimer"] = ['Y']

        # submit the form
        self.browser.submit_selected()
    
    # https://www.journaldev.com/18722/python-static-method
    @staticmethod
    def server_running():
        """Checks the status of the Casesearch servers
        Args: None
        Returns: `True` if server is up, `False` otherwise
        """
        return urlopen(URL).getcode() == 200

# %% [markdown]
# ### Spider

# %%
from __future__ import absolute_import, print_function, unicode_literals
from json import dumps, load
from os import path, makedirs
from random import uniform
import sys
from time import sleep

from tqdm import trange

# from local_browser import Session
from settings import CASE_PAT, CHECKPOINT, HTML_DIR, HTML_FILE

# %%
cd responses
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl/responses

# %%
ls
# Out:
# outputfile.csv  responses/  tidyaddr-js/

# %%
ls ./responses -r

# %%
# !find . -type f ! -name '240*.html' -delete

# %%
class Spider(object):

    def __init__(self, case_type, year, bounds=range(1, 6), gui=False):
        """ Constructor
        Attributes: bounds, year, case_type, WAITING_TIME, disclaimer_form
        """ 
        # Start a Session
        self.browser = Session()
        if not self.browser.server_running(): sys.exit("Server is unavailable at the moment")

        # Handle the disclaimer form on start
        print (self.browser)
        self.browser.disclaimer_form()

        self.WAITING_TIME = 0
        self.case_type = case_type
        self.year = year
        self.bounds = bounds

        if not path.exists(HTML_DIR): makedirs(HTML_DIR)

    def save_response(self):

        # Instantly make your loops show a smart progress meter https://pypi.org/project/tqdm/
        case_range = trange( len(self.bounds), desc="Crawling", leave=True )
        for case_num in case_range:
            # 5 minuet cooldown every 5 minutes
            if case_num and not case_num % 500:
                print("500 CASES SCRAPED. SCRIPT WILL WAIT 5 MINUTES TO RESUME")
                for i in range(300, 0, -1):
                    sleep(1)
                    sys.stdout.write('\r' + "%02d:%02d" % divmod(i, 60))
                    sys.stdout.flush()
            # 
            case = CASE_PAT.format(
                type=self.case_type,
                year=self.year,
                num="{:04d}".format(int(str(self.bounds[case_num])[-4:]))
            )
            # 
            try:
                wait = uniform(0.0, 0.5)
                sleep(wait)
                self.WAITING_TIME += wait
                case_range.set_description("Crawling {}".format(case))
                stripped_html = self.browser.case_id_form(case)
                # print('returend this ' , stripped_html)
                if stripped_html:
                    with open( HTML_FILE.format(case=case) + ".html", 'w' ) as case_file:
                        case_file.write(str(stripped_html))

            # pause process
            except KeyboardInterrupt:
                self.dump_json({
                    "error_case":
                        "{:04d}".format(int(str(self.bounds[case_num])[-4:])),
                        "year": self.year,
                        "type": self.type
                })
                print("Crawling paused at", case)
                break

            # case does not exist
            except IndexError:

                self.dump_json({"error_case": case})
                print(case, "does not exist")
                break

        # close browser and end session
        self.close_sesh()

    def close_sesh(self):
        self.browser.close()

    # write to log
    @staticmethod
    def dump_json(data):

        with open(CHECKPOINT, "r+") as checkpoint:
            checkpoint_data = load(checkpoint)

            for key, val in data.items():
                checkpoint_data[key] = val

            checkpoint_data[key] = data
            checkpoint.seek(0)
            checkpoint.write(dumps(checkpoint_data))
            checkpoint.truncate()

# %% [markdown]
# ## Manually Scrape (optional)

# %%
"""scrape = True
if scrape:
  spider = Spider(
    case_type='O', year=18,
    bounds=range(2244, 9999), gui=False
  )
  spider.save_response()
  wait = spider.WAITING_TIME"""
# Out:
# "scrape = True\nif scrape:\n  spider = Spider(\n    case_type='O', year=18,\n    bounds=range(2244, 9999), gui=False\n  )\n  spider.save_response()\n  wait = spider.WAITING_TIME"

# %% [markdown]
# # Miner

# %% [markdown]
# ## Patterns

# %%
patternsLbl = """Patterns
  Regular expression patterns and string filtering functions implemented in the
  project. This file is intended to only be used as a non-executable script.

  TODO:
      Finish docs

  (\d{1,4}\s[\w\s]{1,20}((?:st(reet)?|ln|lane|ave(nue)?|r(?:oa)?d|highway|hwy|
  dr(?:ive)?|sq(uare)?|tr(?:ai)l|c(?:our)?t|parkway|pkwy|cir(cle)?|ter(?:race)?|
  boulevard|blvd|pl(?:ace)?)\W?(?=\s|$))(\s(apt|block|unit)\W?([A-Z]|\d+))?)
  """

# %%
# https://docs.python.org/3/library/re.html
# Compile a regular expression pattern into a regular expression object, 
# which can be used for matching using its match(), search() and other methods
"""
prog = re.compile(pattern)
result = prog.match(string)
or
result = re.match(pattern, string)
"""
# https://docs.python.org/3/library/re.html#re.compile
from re import compile as re_compile
# https://docs.python.org/3/library/re.html#re.IGNORECASE
from re import I as IGNORECASE
# https://www.geeksforgeeks.org/string-punctuation-in-python/
from string import punctuation

# %%
#
# Create the Patterns for use in the miner
#

PUNCTUATION = punctuation.replace('#', '')  # Replaces all punctuation except '#'

# Regex's to match on.
street_address = re_compile(
    "("  # begin regex group
    "\d{1,4}\s"  # house number
    "[\w\s]{1,20}"  # street name
    "("  # start street type group
    "(?:st(reet)?|ln|lane|ave(nue)?"  # (st)reet, lane, ln, (ave)nue
    "|r(?:oa)?d|highway|hwy|dr(?:ive)?"  # rd, road, hwy, highway, (dr)ive
    "|sq(uare)?|tr(?:ai)l|c(?:our)?t"  # (sq)uare, (tr)ail, ct, court
    "|parkway|pkwy|cir(cle)?|ter(?:race)?"  # parkway, pkwy, (cir)cle, (ter)race
    "|boulevard|blvd|pl(?:ace)?"  # boulevard, bvld, (pl)ace
    "\W?(?=\s|$))"  # look ahead for whitespace or end of string
    ")"  # end street type group
    "(\s(apt|block|unit)(\W|#)?([\d|\D|#-|\W])+)?"  # apt, block, unit number
    ")",  # end regex group
    IGNORECASE  # case insensitive flag
)

# case insensitive delimiter for Titles
TITLE_SPLIT_PAT = re_compile(" vs ", IGNORECASE)

# pattern for Baltimore zip codes
ZIP_STR = "2\d{4}"
ZIP_PAT = re_compile(ZIP_STR)

# regex pattern to capture monetary values between $0.00 and $999,999,999.99
# punctuation insensitive
MONEY_STR = "\$\d{,3},?\d{,3},?\d{,3}\.?\d{2}"
MONEY_PAT = re_compile(MONEY_STR)

NULL_ADDR = re_compile(
    "^("
    "(" + MONEY_STR + ")"
    "|(" + ZIP_STR + ")"
    "|(\d+)"
    "|(" + ZIP_STR + ".*" + MONEY_STR + ")"
    ")$",
    IGNORECASE
)

STRIP_ADDR = re_compile(
    "(balto|" + ZIP_STR + "|md|" + MONEY_STR + ").*",
    IGNORECASE
)


def filter_addr(address):
    try:
      return ''.join(
        street_address.search( 
          address.translate( str.maketrans('','', PUNCTUATION) ) 
        ).group(0)
      )
    except AttributeError:
      return ''

# %% [markdown]
# ## Miner

# %%
"""Miner

TODO:
    Finish docs
    Refactor to lower complexity

"""
# Out:
# 'Miner\n\nTODO:\n    Finish docs\n    Refactor to lower complexity\n\n'

# %%
from __future__ import absolute_import, print_function, unicode_literals
from csv import DictWriter
from json import dump, dumps, load
from os import path

from bs4 import BeautifulSoup
from tqdm import trange

# from patterns import MONEY_PAT, TITLE_SPLIT_PAT, ZIP_PAT, filter_addr
from settings import HTML_FILE, NO_CASE

# %%
# data mining settings
FEATURES = [
    "Filing Date",
    "Case Number",
    "Case Type",
    "Title",
    "Plaintiff",
    "Defendant",
    "Address",
    "Business or Organization Name",
    "Party Type",
]
FIELDS = FEATURES + [ "Zip Code", "Partial Cost" ]
INTERNAL_FIELDS = [ "Business or Organization Name", "Party Type"]

#
# Miner - scan_files, export, scrape, distribute, 
# 
#
class Miner(object):

    def __init__(self, responses, output, debug=False):

        self.responses = responses
        self.output = output
        self.debug = debug
        self.dataset = []
        self.maybe_tax = False
        self.features = [i + ':' for i in FEATURES]

    def scan_files(self):

        case_range = trange(len(self.responses), desc="Mining", leave=True) \
            if not self.debug else range(len(self.responses)) 
        for file_name in case_range:
            with open(
                HTML_FILE.format(case=self.responses[file_name]), 'r'
            ) as html_src: 
                if not self.debug:
                    case_range.set_description(
                        "Mining {}".format(self.responses[file_name])
                    ) 
                feature_list = self.scrape(html_src.read())
                row = self.distribute(feature_list)
                
                if not row:

                    if not path.isfile(NO_CASE):
                        with open(NO_CASE, 'w') as no_case_file:
                            dump([], no_case_file)

                    with open(NO_CASE, "r+") as no_case_file:
                        no_case_data = load(no_case_file)
                        no_case_data.append(str(self.responses[file_name][:-5]))
                        no_case_file.seek(0)
                        no_case_file.write(dumps(sorted(set(no_case_data))))
                        no_case_file.truncate() 
                self.dataset.extend(row)

    def export(self): 

        file_exists = path.isfile(self.output)

        with open(self.output, 'a') as csv_file:
            writer = DictWriter( csv_file,
                fieldnames=[ col for col in FIELDS if col not in INTERNAL_FIELDS ]
            )

            if not file_exists:
                writer.writeheader()

            for row in self.dataset:
                writer.writerow(row)

    def scrape(self, html_data):
        """Scrapes the desired features 
        Args: html_data: <str>, source HTML 
        Returns: scraped_features: <dict>, features scraped and mapped from content
        """

        soup = BeautifulSoup(html_data, "html.parser")

        # Search for the word 'tax in the document'
        if "tax" in soup.text.lower():
            self.maybe_tax = True

        # Create an array from all TR's with the inner HTML for each TR
        # Data we want is stored inside an arbitrary # of 'span' tags inside the TR's.\
        tr_list = soup.find_all("tr")

        # This will create an array for each TR with an array of SPAN values inside.  
        feature_list = []
        for tag in tr_list:
            try:
                # Create an innerhtml array for all spans within a single TR
                tag = [j.string for j in tag.findAll("span")]
                if set(tuple(tag)) & set(self.features):
                    try:
                        # Save the spans inner HTML if its not a header label
                        tag = [i for i in tag if "(each" not in i.lower()]
                    except AttributeError:
                        continue
                    feature_list.append(tag)

            except IndexError:
                continue

        # feature_list is an array [tr] of arrays [spans]. we want this flattened.
        # [tr1span1KEY, tr1span1VALUE, tr1span2KEY, tr1span2VALUE, tr2span1KEY, tr2span1VALUE, ]
        try:
            # flatten multidimensional list
            feature_list = [
                item.replace(':', '')
                for sublist in feature_list for item in sublist
            ]

        except AttributeError:
            pass

        return feature_list

    def distribute(self, feature_list):

        # feature_list ~= [html][tr][spans].innterHTML
        # [tr1span1KEY, tr1span1VALUE, tr1span2KEY, tr1span2VALUE, tr2span1KEY, tr2span1VALUE, ]
        def __pair(list_type):

            # break up elements with n-tuples greater than 2
            def __raw_business(i): return any( x in feature_list[i:i + 2][0] for x in INTERNAL_FIELDS )
            def __feature_list(i): return feature_list[i:i + 2][0] in FEATURES
            condition = __raw_business if list_type else __feature_list
            # then convert list of tuples to dict for faster lookup
            return [ tuple(feature_list[i:i + 2]) for i in range(0, len(feature_list), 2) if condition(i) ]

        raw_business = __pair(1) # [(x1,y1),(x2,y2),(x3,y3)] => INTERNAL_FIELDS
        feature_list = dict(__pair(0)) # FEATURES
        filtered_business = []

        # Party_Type = 'property address' not 'plaintiff' or 'defendant'
        # Input exists 'Business or Org Name' and == an Address
        for label, value in enumerate(raw_business):
            try:
                party_type = value[1].upper()
                section = raw_business[label + 1][0].upper()
                flag1 = party_type == "PROPERTY ADDRESS"
                flag2 = section == "BUSINESS OR ORGANIZATION NAME"
                if flag1 and flag2: filtered_business.append(raw_business[label + 1])
            except IndexError:
                print("Party Type issue at Case", feature_list["Case Number"])
        scraped_features = []
        for address in filtered_business:
            str_address = filter_addr(str(address[-1]))
            temp_features = {
                key: value for key, value in feature_list.items()
                if key in ["Title", "Case Type", "Case Number", "Filing Date"]
            }
            if temp_features["Case Type"].upper() == "FORECLOSURE":
                temp_features["Case Type"] = "Mortgage"

            elif temp_features["Case Type"].upper() == "FORECLOSURE RIGHTS OF REDEMPTION" and self.maybe_tax:
                temp_features["Case Type"] = "Tax"
            
            else: # break out of the rest of the loop if case type is neither
              continue

            if 'Title' not in temp_features: 
              # print('feature_list');
              # print(feature_list);
              # print('\n \n raw_business');
              # print(raw_business);
              continue

            # break up Title feature into Plaintiff and Defendant
            try:
                temp_features["Plaintiff"], temp_features["Defendant"] = \
                    TITLE_SPLIT_PAT.split(temp_features["Title"])

            except ValueError:
                temp_features["Plaintiff"], temp_features["Defendant"] = \
                    (", ")

            temp_features["address"] = \
                str_address if str_address else address[-1]

            temp_features["Zip Code"] = ''.join(ZIP_PAT.findall(address[-1]))

            temp_features["Partial Cost"] = ''.join(
                MONEY_PAT.findall(address[-1])
            )

            scraped_features.append(temp_features)
            temp_features = {}

        return scraped_features

# %%
from settings import CHECKPOINT, HTML_DIR
from os import path, remove, walk

temp_output = "temp_data.csv"

# Get all files in directory
file_array = [filenames for (dirpath, dirnames, filenames) in walk(HTML_DIR)][0]

top5 = file_array[:1]

# %%
cd ../
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl

# %%
cd responses
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl/responses

# %%
ls
# Out:
# outputfile.csv  responses/  tidyaddr-js/

# %%
file_array

# %%
miner = Miner(file_array, temp_output)

# %%
miner.scan_files()
# Out:
# Mining 24O18001396.html:   0%|          | 1/2394 [00:00<27:57,  1.43it/s]
# Party Type issue at Case 24O18001395
# Mining 24O18001397.html:   0%|          | 2/2394 [00:01<28:40,  1.39it/s]
# Party Type issue at Case 24O18001396
# Mining 24O18001398.html:   0%|          | 3/2394 [00:02<29:12,  1.36it/s]
# Party Type issue at Case 24O18001397
# Mining 24O18001399.html:   0%|          | 4/2394 [00:02<29:34,  1.35it/s]
# Party Type issue at Case 24O18001398
# Mining 24O18001400.html:   0%|          | 5/2394 [00:03<29:23,  1.36it/s]
# Party Type issue at Case 24O18001399
# Mining 24O18001401.html:   0%|          | 6/2394 [00:04<29:54,  1.33it/s]
# Party Type issue at Case 24O18001400
# Party Type issue at Case 24O18000392
# Mining 24O18000394.html: 100%|█████████▉| 2393/2394 [29:46<00:00,  1.36it/s]
# Party Type issue at Case 24O18000393
# Mining 24O18000394.html: 100%|██████████| 2394/2394 [29:47<00:00,  1.34it/s]
# Party Type issue at Case 24O18000394

# %%
miner.export()

# %%
miner.output = 'temp_dat.csv'

# %% [markdown]
# ## Manually Mine (optional)

# %%
"""
scrapethisfile = '24O19000982.html'
with open( HTML_FILE.format(case=scrapethisfile), 'r' ) as html_src:
  print( scrapethisfile);
  feature_list = scrape(html_src.read())
  print(feature_list);
  row = distribute(feature_list)
"""

# %%
soup = ''
scrapethisfile = '24O19000982.html'
with open( HTML_FILE.format(case=scrapethisfile), 'r' ) as html_src:
  souptxt = html_src.read()
  soup = BeautifulSoup(souptxt, "html.parser")

# %%
from settings import CHECKPOINT, HTML_DIR
from os import path, remove, walk

temp_output = "temp_dat.csv"
file_array = [filenames for (dirpath, dirnames, filenames) in walk(HTML_DIR)][0]
top5 = [ file_array[41] ]

# %%
miner = Miner(top5, temp_output)

# %%
miner.scan_files()

# %% [markdown]
# # Cleaner

# %%
cleanerTxt = """
  Cleaner

  This module implements post-scraping cleaning processes on the raw initial
  dataset. Processes include stripping excess strings off Address values,
  removing Zip Code and Partial Cost values mislabeled as Address, and merging
  rows containing blank values in alternating features.

  The script works as an internal module for Close Crawl, but can be executed
  as a standalone to manually process datasets:

      $ python cleaner.py <path/to/old/dataset> <path/of/new/dataset>
  """

# %%
from __future__ import absolute_import, print_function, unicode_literals
from pandas import DataFrame, concat, read_csv, to_datetime

# %%
class Cleaner(object):
    """Class object for cleaning the raw dataset extracted after the initial
    scraping
    """

    def __init__(self, path):
        """Constructor for Cleaner
        Args: path (`str`): path to input CSV dataset
        Attributes:
            df (`pandas.core.frame.DataFrame`): initial DataFrame
            columns (`list` of `str`): columns of the DataFrame
            clean_df (`pandas.core.frame.DataFrame`): final DataFrame to be outputted
        """

        self.df = self.prettify(read_csv(path))

        self.columns = list(self.df)
        self.clean_df = []

    @staticmethod
    def prettify(df, internal=True):
        """Drops duplicates, sorts and fills missing values in the DataFrame to make it manageable.
        Args: df (`pandas.core.frame.DataFrame`): DataFrame to be managed
            internal (`bool`, optional): flag for determining state of DataFrame
        Returns: df (`pandas.core.frame.DataFrame`): organized DataFrame
        """

        df = df.drop_duplicates()
        df["Filing Date"] = to_datetime(df["Filing Date"])
        df.sort_values( ["Filing Date", "Case Number", "Address"], ascending=[True] * 3, inplace=True )

        if internal:
            df["Zip Code"] = df["Zip Code"].fillna(0.0).astype(int)
            df["Zip Code"] = df["Zip Code"].replace(0, '')

        return df

    def clean_addr(self):
        """Cleans excess strings off Address values and removes Zip Code and
        Partial Cost values mislabeled as Address. 
        Args: None 
        Returns: None
        """
        print("addresses...", self.df.size)
        def clean_string(addr):
            """Applies regular expressions and other filters on Address values
            Args: addr (`str`): Address value to be filtered
            Returns: addr (`str`): filtered Address value
            """
            # if value does not match the street_address pattern
            if not filter_addr(addr):  # patterns.filter_addr
                if NULL_ADDR.sub('', addr):  # value may contain valid Address
                    return str( STRIP_ADDR.sub(  '', addr)  # strip off Zip Code and Partial Cost
                    ).translate( {ord(c): None for c in punctuation} ).strip()  # strip off punctuations
            return addr
        print("Cleaning addresses...", end=" ")
        self.df["Address"] = self.df["Address"].apply( lambda x: clean_string(x)  )
        self.df["Address"] = self.df["Address"].apply( lambda x: NULL_ADDR.sub('', x)  )

        # replace empty string values with NULL
        self.df["Zip Code"] = self.df["Zip Code"].replace('', float("nan"))
        self.df["Address"] = self.df["Address"].replace('', float("nan"))
        print("Done")

    @staticmethod
    def combine_rows(row):
        """Merges rows after filtering out common values 
        Args: row (`list` of `list` of `str`): groupby("Case Number") rows 
        Returns: (`list` of `str`): merged row
        """

        def __filter_tuple(col):
            """Filters common values from rows
            Args: col (`tuple` of `str`): values per column
            Returns: value (`str`): common value found per mergeable rows
            """

            for value in set(col):
                if value == value:  # equivalent to value != NaN
                    return value

        return [__filter_tuple(x) for x in zip(*row)]

    @staticmethod
    def mergeable(bool_vec):
        """Determines if groupby("Case Number") rows are mergeable
        Example:
            bool_vec = [
                [True, True, True, True, True, True, False, True, True],
                [True, True, True, True, True, True, True, False, False],
                [True, True, True, True, True, True, False, False, False]
            ]
            __sum_col(bool_vec) -> [3, 3, 3, 3, 3, 3, 1, 1, 1]
            __bool_pat(__sum_col(bool_vec)) -> True
        Args: bool_vec (`list` of `bool`): represents non-NULL values
        Returns: (`bool`): True if rows are mergeable
        """

        def __sum_col():
            """Sums columns 
            Args: None 
            Returns:
                (`list` of `int`): sum of columns
            """
            return [sum(x) for x in zip(*bool_vec)]

        def __bool_pat(row):
            """Determines mergeability
            Args: None
            Returns: (`bool`): True if rows are mergeable
            """
            return set(row[-3:]) == set([1]) and set(row[:-3]) != set([1])

        return True if __bool_pat(__sum_col()) else False

    def merge_nulls(self):
        """Splits DataFrames into those with NULL values to be merged, and then later merged with the original DataFrame 
        Args: None 
        Returns: None
        """
        print("Merging rows...", end=" ")
        # filter out rows with any NULL values
        origin_df = self.df.dropna()
        
        # filter out rows only with NULL values
        null_df = self.df[self.df.isnull().any(axis=1)]

        # boolean representation of the DataFrame with NULL values
        bool_df = null_df.notnull()

        # (`list` of `dict` of `str` : `str`) to be converted to a DataFrame
        new_df = []

        for i in null_df["Case Number"].unique():
            bool_row = bool_df[null_df["Case Number"] == i]
            new_row = null_df[null_df["Case Number"] == i]

            # if the rows are mergeable, combine them
            if self.mergeable(bool_row.values):
                new_row = self.combine_rows(new_row.values.tolist())

                new_df.append(
                    {
                        feature: value
                        for feature, value in zip(self.columns, new_row)
                    }
                )

            # else, treat them individually
            else:
                new_row = new_row.values.tolist()

                for row in new_row:
                    new_df.append(
                        {
                            feature: value
                            for feature, value in zip(self.columns, row)
                        }
                    )

        # merge the DataFrames back
        self.clean_df = concat(
            [origin_df, DataFrame(new_df)]
        ).reset_index(drop=True)

        # prettify the new DataFrame
        self.clean_df = self.prettify(
            self.clean_df[self.columns], internal=False
        )

        print("Done")

    def init_clean(self):
        """Initializes cleaning process

        Args:
            None

        Returns:
            None
        """

        self.clean_addr()
        self.merge_nulls()

    def download(self, output_name):
        """Downloads the cleaned and manipulated DataFrame into a CSV file

        Args:
            output_name (`str`): path of the new output file

        Returns:
            None
        """
        self.clean_df.to_csv(output_name, index=False)

# %%
def prettify(df, internal=True):
    """Drops duplicates, sorts and fills missing values in the DataFrame to make it manageable.
    Args: df (`pandas.core.frame.DataFrame`): DataFrame to be managed
        internal (`bool`, optional): flag for determining state of DataFrame
    Returns: df (`pandas.core.frame.DataFrame`): organized DataFrame
    """

    df = df.drop_duplicates()
    df["Filing Date"] = to_datetime(df["Filing Date"])
    df.sort_values( ["Filing Date", "Case Number", "Address"], ascending=[True] * 3, inplace=True )

    if internal:
        df["Zip Code"] = df["Zip Code"].fillna(0.0).astype(int)
        df["Zip Code"] = df["Zip Code"].replace(0, '')

    return df

prettify( read_csv("temp_dat.csv") )

# %%
temp_output = "temp_data.csv"
output = 'outputfile.csv'
df_obj = Cleaner(temp_output)
df_obj.init_clean()
df_obj.download(output)

# %% [markdown]
# # Tidy Addr

# %%
ls
# Out:
#  checkpoint.json  'Close Crawl.ipynb'   output.csv     temp_data.csv
#  cliargs.py        modules/             __pycache__/   _version.py
#  cli.py            no_case.json         responses/

# %%
cd responses
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl/responses

# %%
# !git clone https://github.com/BNIA/tidyaddr-js.git

#node tidyaddr.js clean-csv \<your-input-file\> \<your-output-file\>
# Out:
# fatal: destination path 'tidyaddr-js' already exists and is not an empty directory.

# %%
! cp outputfile.csv tidyaddr-js/outputfiles.csv

# %%
! npm install
# Out:
# npm ERR! path ../atob/bin/atob.js
# npm ERR! code ENOTSUP
# npm ERR! errno -95
# npm ERR! syscall symlink
# npm ERR! nospc ENOTSUP: operation not supported on socket, symlink '../atob/bin/atob.js' -> '/gdrive/My Drive/colabs/vitalSigns/close_crawl/responses/tidyaddr-js/node_modules/.bin/atob'
# npm ERR! nospc There appears to be insufficient space on your system to finish.
# npm ERR! nospc Clear up some disk space and try again.
#
# npm ERR! A complete log of this run can be found in:
# npm ERR!     /root/.npm/_logs/2020-06-10T19_10_19_565Z-debug.log

# %%
cd tidyaddr-js
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl/responses/tidyaddr-js

# %%
ls
# Out:
# dev/     LICENSE        outputfiles.csv  README.md    todo.todo
# init.js  node_modules/  package.json     tidyaddr.js

# %%
import pandas as pd
data = pd.read_csv('outputfiles.csv')
data['address'] = data['Address']
data = data.drop( ['Address'], axis=1)
data.to_csv('outputProperAddress.csv', index=False)
data
# Out:
#      Filing Date  Case Number  ... Partial Cost                   address
# 0     2014-04-24  24O18000750  ...          NaN        1508 Ralworth Road
# 1     2015-02-02  24O18000232  ...  $116,603.30          4221 Belvieu Ave
# 2     2017-05-17  24O18000906  ...  $186,398.75      2802 Silver Hill Ave
# 3     2018-01-02  24O18000001  ...   $95,386.42          1222 Delbert Ave
# 4     2018-01-02  24O18000006  ...  $322,711.69  1212 West Lombard Street
# ...          ...          ...  ...          ...                       ...
# 2418  2018-12-31  24O18002390  ...  $453,040.00         3400 Dennlyn Road
# 2419  2018-12-31  24O18002391  ...  $204,229.09        4405 Furley Avenue
# 2420  2018-12-31  24O18002392  ...  $135,399.49       3670 Clarenell Road
# 2421  2018-12-31  24O18002393  ...  $154,470.76         3 N Monastery Ave
# 2422  2018-12-31  24O18002394  ...  $127,582.64         907 Stamford Road
#
# [2423 rows x 9 columns]

# %%
! node tidyaddr.js clean-csv 'outputProperAddress.csv' 'final.csv'
# Out:
# Streaming output truncated to the last 5000 lines.
#     replace: 'avenue',
#     original: '5510 Greenhill Ave',
#     originalLen: 18,
#     subbed: '5510 Greenhill avenue',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 10,
#     len: 6,
#     end: 16,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4101 Main Avenue',
#     originalLen: 16,
#     subbed: '4101 Main avenue',
#     subbedLen: 16 } ]
# [ { found: 'Avenue',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5319 Plainfield Avenue',
#     originalLen: 22,
#     subbed: '5319 Plainfield avenue',
#     subbedLen: 22 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3810 Hillsdale Road',
#     originalLen: 19,
#     subbed: '3810 Hillsdale road',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3715 Colborne Road',
#     originalLen: 18,
#     subbed: '3715 Colborne road',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 10,
#     len: 6,
#     end: 16,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '823 Ponca Street',
#     originalLen: 16,
#     subbed: '823 Ponca street',
#     subbedLen: 16 } ]
# [ { found: 'Street',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '724 North Grantley Street',
#     originalLen: 25,
#     subbed: '724 North Grantley street',
#     subbedLen: 25 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3646 Lyndale Avenue',
#     originalLen: 19,
#     subbed: '3646 Lyndale avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2906 Clifton Avenue',
#     originalLen: 19,
#     subbed: '2906 Clifton avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5404 Belle Vista Avenue',
#     originalLen: 23,
#     subbed: '5404 Belle Vista avenue',
#     subbedLen: 23 } ]
# [ { found: 'Road',
#     start: 11,
#     len: 4,
#     end: 15,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '5625 Sagra Road',
#     originalLen: 15,
#     subbed: '5625 Sagra road',
#     subbedLen: 15 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5109 Pembridge Avenue',
#     originalLen: 21,
#     subbed: '5109 Pembridge avenue',
#     subbedLen: 21 } ]
# [ { found: 'Ave',
#     start: 13,
#     len: 3,
#     end: 16,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '2620 Brendan Ave',
#     originalLen: 16,
#     subbed: '2620 Brendan avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4502 Frederick Avenue',
#     originalLen: 21,
#     subbed: '4502 Frederick avenue',
#     subbedLen: 21 } ]
# [ { found: '',
#     start: 26,
#     len: 0,
#     end: 26,
#     match: [ '(?i)(?=\\S+way)', '\\b' ],
#     replace: null,
#     original: '3511 West Northern Parkway',
#     originalLen: 26,
#     subbed: '3511 West Northern Parkway',
#     subbedLen: 26 } ]
# [ { found: 'Drive',
#     start: 17,
#     len: 5,
#     end: 22,
#     match: '\\bdrive\\b',
#     replace: 'drive',
#     original: '4927 Herring Run Drive',
#     originalLen: 22,
#     subbed: '4927 Herring Run drive',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '523 Annabel Avenue',
#     originalLen: 18,
#     subbed: '523 Annabel avenue',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2610 Huron Street',
#     originalLen: 17,
#     subbed: '2610 Huron street',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3817 Bowers Avenue',
#     originalLen: 18,
#     subbed: '3817 Bowers avenue',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1829 North Port Street',
#     originalLen: 22,
#     subbed: '1829 North Port street',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4401 Vesta Avenue',
#     originalLen: 17,
#     subbed: '4401 Vesta avenue',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '7219 Gough Street',
#     originalLen: 17,
#     subbed: '7219 Gough street',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1128 Poplar Grove Street',
#     originalLen: 24,
#     subbed: '1128 Poplar Grove street',
#     subbedLen: 24 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1337 W 41st Street',
#     originalLen: 18,
#     subbed: '1337 W 41st street',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 19,
#     len: 4,
#     end: 23,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '956 N Franklintown Road',
#     originalLen: 23,
#     subbed: '956 N Franklintown road',
#     subbedLen: 23 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1827 Chilton Street',
#     originalLen: 19,
#     subbed: '1827 Chilton street',
#     subbedLen: 19 } ]
# [ { found: 'Drive',
#     start: 18,
#     len: 5,
#     end: 23,
#     match: '\\bdrive\\b',
#     replace: 'drive',
#     original: '4414 Falls Bridge Drive',
#     originalLen: 23,
#     subbed: '4414 Falls Bridge drive',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4313 Norfolk Avenue',
#     originalLen: 19,
#     subbed: '4313 Norfolk avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1510 East Lanvale Street',
#     originalLen: 24,
#     subbed: '1510 East Lanvale street',
#     subbedLen: 24 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4401 Kathland Avenue',
#     originalLen: 20,
#     subbed: '4401 Kathland avenue',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '5002 Levindale Road',
#     originalLen: 19,
#     subbed: '5002 Levindale road',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 9,
#     len: 6,
#     end: 15,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3703 6th Street',
#     originalLen: 15,
#     subbed: '3703 6th street',
#     subbedLen: 15 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2218 Sidney Avenue',
#     originalLen: 18,
#     subbed: '2218 Sidney avenue',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '728 McKewin Avenue',
#     originalLen: 18,
#     subbed: '728 McKewin avenue',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2206 North Calvert Street',
#     originalLen: 25,
#     subbed: '2206 North Calvert street',
#     subbedLen: 25 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '2801 Allendale Road',
#     originalLen: 19,
#     subbed: '2801 Allendale road',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '64 South Morley Street',
#     originalLen: 22,
#     subbed: '64 South Morley street',
#     subbedLen: 22 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '5403 Bucknell Road',
#     originalLen: 18,
#     subbed: '5403 Bucknell road',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1811 Penrose Avenue',
#     originalLen: 19,
#     subbed: '1811 Penrose avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3850 Elmly Avenue',
#     originalLen: 17,
#     subbed: '3850 Elmly avenue',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3303 Cardenas Avenue',
#     originalLen: 20,
#     subbed: '3303 Cardenas avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3213 Evergreen Avenue',
#     originalLen: 21,
#     subbed: '3213 Evergreen avenue',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 16,
#     len: 4,
#     end: 20,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4928 Greencrest Road',
#     originalLen: 20,
#     subbed: '4928 Greencrest road',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1327 E North Avenue',
#     originalLen: 19,
#     subbed: '1327 E North avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '315 McAllister Street',
#     originalLen: 21,
#     subbed: '315 McAllister street',
#     subbedLen: 21 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3102 McElderry Street',
#     originalLen: 21,
#     subbed: '3102 McElderry street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3067 Mayfield Avenue',
#     originalLen: 20,
#     subbed: '3067 Mayfield avenue',
#     subbedLen: 20 } ]
# [ { found: 'Dr',
#     start: 16,
#     len: 2,
#     end: 18,
#     match: '\\bdr\\b',
#     replace: 'drive',
#     original: '2643 Northshire Dr',
#     originalLen: 18,
#     subbed: '2643 Northshire drive',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4628 Harcourt Road',
#     originalLen: 18,
#     subbed: '4628 Harcourt road',
#     subbedLen: 18 } ]
# []
# [ { found: 'Place',
#     start: 11,
#     len: 5,
#     end: 16,
#     match: '\\bplace\\b',
#     replace: 'place',
#     original: '2237 Eutaw Place',
#     originalLen: 16,
#     subbed: '2237 Eutaw place',
#     subbedLen: 16 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '124 N Culver Street',
#     originalLen: 19,
#     subbed: '124 N Culver street',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5200 Powhatan Avenue',
#     originalLen: 20,
#     subbed: '5200 Powhatan avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4331 Hamilton Avenue',
#     originalLen: 20,
#     subbed: '4331 Hamilton avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3400 West Rogers Avenue',
#     originalLen: 23,
#     subbed: '3400 West Rogers avenue',
#     subbedLen: 23 } ]
# [ { found: 'Street',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '110 North Aisquith Street',
#     originalLen: 25,
#     subbed: '110 North Aisquith street',
#     subbedLen: 25 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2036 Whistler Avenue',
#     originalLen: 20,
#     subbed: '2036 Whistler avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '518 South Lehigh Street',
#     originalLen: 23,
#     subbed: '518 South Lehigh street',
#     subbedLen: 23 } ]
# [ { found: 'Street',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1404 McCulloh Street',
#     originalLen: 20,
#     subbed: '1404 McCulloh street',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5125 Benton Heights Avenue',
#     originalLen: 26,
#     subbed: '5125 Benton Heights avenue',
#     subbedLen: 26 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5008 Hampshire Avenue',
#     originalLen: 21,
#     subbed: '5008 Hampshire avenue',
#     subbedLen: 21 } ]
# [ { found: 'Ave',
#     start: 11,
#     len: 3,
#     end: 14,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '4426 Raspe Ave',
#     originalLen: 14,
#     subbed: '4426 Raspe avenue',
#     subbedLen: 17 } ]
# [ { found: 'St',
#     start: 9,
#     len: 2,
#     end: 11,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '3602 5th St',
#     originalLen: 11,
#     subbed: '3602 5th street',
#     subbedLen: 15 } ]
# [ { found: 'Ave',
#     start: 18,
#     len: 3,
#     end: 21,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '3023 Chesterfield Ave',
#     originalLen: 21,
#     subbed: '3023 Chesterfield avenue',
#     subbedLen: 24 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '6916 Conley Street',
#     originalLen: 18,
#     subbed: '6916 Conley street',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2901 Boston Street Unit 206  Baltimore MD 2122424660237',
#     originalLen: 55,
#     subbed: '2901 Boston streetUnit 206  Baltimore MD 2122424660237',
#     subbedLen: 54 } ]
# [ { found: 'Ave',
#     start: 11,
#     len: 3,
#     end: 14,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '3721 Belle Ave',
#     originalLen: 14,
#     subbed: '3721 Belle avenue',
#     subbedLen: 17 } ]
# [ { found: 'Road',
#     start: 19,
#     len: 4,
#     end: 23,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4424 Old Frederick Road',
#     originalLen: 23,
#     subbed: '4424 Old Frederick road',
#     subbedLen: 23 } ]
# [ { found: '',
#     start: 20,
#     len: 0,
#     end: 20,
#     match: [ '(?i)(?=\\S+way)', '\\b' ],
#     replace: null,
#     original: '3621 Pulaski Highway',
#     originalLen: 20,
#     subbed: '3621 Pulaski Highway',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1344 Pentwood Road',
#     originalLen: 18,
#     subbed: '1344 Pentwood road',
#     subbedLen: 18 } ]
# [ { found: 'Ave',
#     start: 18,
#     len: 3,
#     end: 21,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '6711 Park Heights Ave',
#     originalLen: 21,
#     subbed: '6711 Park Heights avenue',
#     subbedLen: 24 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '402 S Robinson Street',
#     originalLen: 21,
#     subbed: '402 S Robinson street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1253 East Belvedere Avenue',
#     originalLen: 26,
#     subbed: '1253 East Belvedere avenue',
#     subbedLen: 26 } ]
# [ { found: 'Road',
#     start: 17,
#     len: 4,
#     end: 21,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '2519 Resterstown Road',
#     originalLen: 21,
#     subbed: '2519 Resterstown road',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5602 Hilltop Avenue',
#     originalLen: 19,
#     subbed: '5602 Hilltop avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2016 Whistler Avenue',
#     originalLen: 20,
#     subbed: '2016 Whistler avenue',
#     subbedLen: 20 } ]
# [ { found: 'Ave',
#     start: 16,
#     len: 3,
#     end: 19,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '1620 Druid Hill Ave',
#     originalLen: 19,
#     subbed: '1620 Druid Hill avenue',
#     subbedLen: 22 } ]
# [ { found: 'Drive',
#     start: 11,
#     len: 5,
#     end: 16,
#     match: '\\bdrive\\b',
#     replace: 'drive',
#     original: '913 Marlau Drive',
#     originalLen: 16,
#     subbed: '913 Marlau drive',
#     subbedLen: 16 } ]
# [ { found: 'Ave',
#     start: 14,
#     len: 3,
#     end: 17,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '5511 Lynnview Ave',
#     originalLen: 17,
#     subbed: '5511 Lynnview avenue',
#     subbedLen: 20 } ]
# [ { found: 'Ave',
#     start: 10,
#     len: 3,
#     end: 13,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '4603 Mary Ave',
#     originalLen: 13,
#     subbed: '4603 Mary avenue',
#     subbedLen: 16 } ]
# [ { found: 'St',
#     start: 9,
#     len: 2,
#     end: 11,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '3437 Ash St',
#     originalLen: 11,
#     subbed: '3437 Ash street',
#     subbedLen: 15 } ]
# [ { found: 'Ave',
#     start: 13,
#     len: 3,
#     end: 16,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '6 N Abington Ave',
#     originalLen: 16,
#     subbed: '6 N Abington avenue',
#     subbedLen: 19 } ]
# [ { found: 'Lane',
#     start: 10,
#     len: 4,
#     end: 14,
#     match: '\\blane\\b',
#     replace: 'lane',
#     original: '2216 Koko Lane',
#     originalLen: 14,
#     subbed: '2216 Koko lane',
#     subbedLen: 14 } ]
# [ { found: 'Road',
#     start: 16,
#     len: 4,
#     end: 20,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1932 Hillenwood Road',
#     originalLen: 20,
#     subbed: '1932 Hillenwood road',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '701 Venable Avenue',
#     originalLen: 18,
#     subbed: '701 Venable avenue',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4302 Ridgewood Avenue',
#     originalLen: 21,
#     subbed: '4302 Ridgewood avenue',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3817 Norfolk Avenue',
#     originalLen: 19,
#     subbed: '3817 Norfolk avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5606 Bland Avenue',
#     originalLen: 17,
#     subbed: '5606 Bland avenue',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '339 South Striker Street',
#     originalLen: 24,
#     subbed: '339 South Striker street',
#     subbedLen: 24 } ]
# [ { found: 'Lane',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\blane\\b',
#     replace: 'lane',
#     original: '2813 Ruscombe Lane',
#     originalLen: 18,
#     subbed: '2813 Ruscombe lane',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5013 Anntana Avenue',
#     originalLen: 19,
#     subbed: '5013 Anntana avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3015 Arunah Avenue',
#     originalLen: 18,
#     subbed: '3015 Arunah avenue',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4018 Carlisle Avenue',
#     originalLen: 20,
#     subbed: '4018 Carlisle avenue',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 18,
#     len: 4,
#     end: 22,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '6929 Reisterstown Road',
#     originalLen: 22,
#     subbed: '6929 Reisterstown road',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3435 Piedmont Avenue',
#     originalLen: 20,
#     subbed: '3435 Piedmont avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '449 Grindall Street',
#     originalLen: 19,
#     subbed: '449 Grindall street',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2233 Saint Paul Street',
#     originalLen: 22,
#     subbed: '2233 Saint Paul street',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5105 Frederick Avenue',
#     originalLen: 21,
#     subbed: '5105 Frederick avenue',
#     subbedLen: 21 } ]
# [ { found: 'Terrace',
#     start: 11,
#     len: 7,
#     end: 18,
#     match: '\\bterrace\\b',
#     replace: 'terrace',
#     original: '5007 Edgar Terrace',
#     originalLen: 18,
#     subbed: '5007 Edgar terrace',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2906 Huron Street',
#     originalLen: 17,
#     subbed: '2906 Huron street',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '618 Harwood Avenue',
#     originalLen: 18,
#     subbed: '618 Harwood avenue',
#     subbedLen: 18 } ]
# [ { found: 'Ave',
#     start: 14,
#     len: 3,
#     end: 17,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '137 S Collins Ave',
#     originalLen: 17,
#     subbed: '137 S Collins avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4501 Seifert Avenue',
#     originalLen: 19,
#     subbed: '4501 Seifert avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '203 North Belnord Avenue',
#     originalLen: 24,
#     subbed: '203 North Belnord avenue',
#     subbedLen: 24 } ]
# [ { found: 'Street',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '434 South Smallwood Street',
#     originalLen: 26,
#     subbed: '434 South Smallwood street',
#     subbedLen: 26 } ]
# [ { found: 'Street',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3402 West Mulberry Street',
#     originalLen: 25,
#     subbed: '3402 West Mulberry street',
#     subbedLen: 25 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4905 Anntana Avenue',
#     originalLen: 19,
#     subbed: '4905 Anntana avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4205 Shamrock Avenue',
#     originalLen: 20,
#     subbed: '4205 Shamrock avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2068 Rockrose Avenue',
#     originalLen: 20,
#     subbed: '2068 Rockrose avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '4375 Parkton Street',
#     originalLen: 19,
#     subbed: '4375 Parkton street',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1220 James Street',
#     originalLen: 17,
#     subbed: '1220 James street',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '924 South Decker Avenue',
#     originalLen: 23,
#     subbed: '924 South Decker avenue',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5511 Wesley Avenue',
#     originalLen: 18,
#     subbed: '5511 Wesley avenue',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4208 Federick Road',
#     originalLen: 18,
#     subbed: '4208 Federick road',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5943 Lillyan Avenue',
#     originalLen: 19,
#     subbed: '5943 Lillyan avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 21,
#     len: 6,
#     end: 27,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2620 East Strathmore Avenue',
#     originalLen: 27,
#     subbed: '2620 East Strathmore avenue',
#     subbedLen: 27 } ]
# [ { found: 'Boulevard',
#     start: 14,
#     len: 9,
#     end: 23,
#     match: '\\bboulevard\\b',
#     replace: 'boulevard',
#     original: '710 Broadview Boulevard',
#     originalLen: 23,
#     subbed: '710 Broadview boulevard',
#     subbedLen: 23 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3101 Hillsdale Road',
#     originalLen: 19,
#     subbed: '3101 Hillsdale road',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1527 Ralworth Road',
#     originalLen: 18,
#     subbed: '1527 Ralworth road',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3305 Ravenwood Avenue',
#     originalLen: 21,
#     subbed: '3305 Ravenwood avenue',
#     subbedLen: 21 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2418 Baker Street',
#     originalLen: 17,
#     subbed: '2418 Baker street',
#     subbedLen: 17 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '5217 Harford Road',
#     originalLen: 17,
#     subbed: '5217 Harford road',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4019 Raymonn Avenue',
#     originalLen: 19,
#     subbed: '4019 Raymonn avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1809 Riggs Avenue',
#     originalLen: 17,
#     subbed: '1809 Riggs avenue',
#     subbedLen: 17 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4513 Harcourt Road',
#     originalLen: 18,
#     subbed: '4513 Harcourt road',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2026 North Bentalou Street',
#     originalLen: 26,
#     subbed: '2026 North Bentalou street',
#     subbedLen: 26 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2202 Mayfield Avenue',
#     originalLen: 20,
#     subbed: '2202 Mayfield avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '725 East Preston Street',
#     originalLen: 23,
#     subbed: '725 East Preston street',
#     subbedLen: 23 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '6918 Gough Street',
#     originalLen: 17,
#     subbed: '6918 Gough street',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4300 Powell Avenue',
#     originalLen: 18,
#     subbed: '4300 Powell avenue',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4871 Melbourne Road',
#     originalLen: 19,
#     subbed: '4871 Melbourne road',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1310 Sherwood Avenue',
#     originalLen: 20,
#     subbed: '1310 Sherwood avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3627 Keystone Avenue',
#     originalLen: 20,
#     subbed: '3627 Keystone avenue',
#     subbedLen: 20 } ]
# [ { found: 'Terrace',
#     start: 16,
#     len: 7,
#     end: 23,
#     match: '\\bterrace\\b',
#     replace: 'terrace',
#     original: '2335 Montebello Terrace',
#     originalLen: 23,
#     subbed: '2335 Montebello terrace',
#     subbedLen: 23 } ]
# [ { found: 'Cir',
#     start: 11,
#     len: 3,
#     end: 14,
#     match: '\\bcir\\b',
#     replace: 'circle',
#     original: '3909 Inner Cir',
#     originalLen: 14,
#     subbed: '3909 Inner circle',
#     subbedLen: 17 } ]
# [ { found: 'Ave',
#     start: 12,
#     len: 3,
#     end: 15,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '5905 Sefton Ave',
#     originalLen: 15,
#     subbed: '5905 Sefton avenue',
#     subbedLen: 18 } ]
# [ { found: 'Rd',
#     start: 11,
#     len: 2,
#     end: 13,
#     match: '\\brd\\b',
#     replace: 'road',
#     original: '1008 Upnor Rd',
#     originalLen: 13,
#     subbed: '1008 Upnor road',
#     subbedLen: 15 } ]
# [ { found: 'Ave',
#     start: 15,
#     len: 3,
#     end: 18,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '3618 Bellevale Ave',
#     originalLen: 18,
#     subbed: '3618 Bellevale avenue',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5371 Cuthbert Avenue',
#     originalLen: 20,
#     subbed: '5371 Cuthbert avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3216 McElderry Street',
#     originalLen: 21,
#     subbed: '3216 McElderry street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 21,
#     len: 6,
#     end: 27,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3100 West Strathmore Avenue',
#     originalLen: 27,
#     subbed: '3100 West Strathmore avenue',
#     subbedLen: 27 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4642 Pall Mall Road',
#     originalLen: 19,
#     subbed: '4642 Pall Mall road',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3007 Glenmore Avenue',
#     originalLen: 20,
#     subbed: '3007 Glenmore avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1333 James Street',
#     originalLen: 17,
#     subbed: '1333 James street',
#     subbedLen: 17 } ]
# [ { found: 'Ave',
#     start: 11,
#     len: 3,
#     end: 14,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '5104 Belle Ave',
#     originalLen: 14,
#     subbed: '5104 Belle avenue',
#     subbedLen: 17 } ]
# [ { found: 'Ave',
#     start: 14,
#     len: 3,
#     end: 17,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '1449 Gittings Ave',
#     originalLen: 17,
#     subbed: '1449 Gittings avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '912 South Curley Street',
#     originalLen: 23,
#     subbed: '912 South Curley street',
#     subbedLen: 23 } ]
# [ { found: 'Court',
#     start: 13,
#     len: 5,
#     end: 18,
#     match: '\\bcourt\\b',
#     replace: 'court',
#     original: '3224 Doycron Court',
#     originalLen: 18,
#     subbed: '3224 Doycron court',
#     subbedLen: 18 } ]
# [ { found: 'Blvd',
#     start: 16,
#     len: 4,
#     end: 20,
#     match: '\\bblvd\\b',
#     replace: 'boulevard',
#     original: '4801 Loch Raven Blvd',
#     originalLen: 20,
#     subbed: '4801 Loch Raven boulevard',
#     subbedLen: 25 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3807 Elmora Avenue',
#     originalLen: 18,
#     subbed: '3807 Elmora avenue',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4009 Deepwood Road',
#     originalLen: 18,
#     subbed: '4009 Deepwood road',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1207 Limit Avenue',
#     originalLen: 17,
#     subbed: '1207 Limit avenue',
#     subbedLen: 17 } ]
# [ { found: 'Road',
#     start: 19,
#     len: 4,
#     end: 23,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4127 Crest Heights Road',
#     originalLen: 23,
#     subbed: '4127 Crest Heights road',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '907 Beaumont Avenue',
#     originalLen: 19,
#     subbed: '907 Beaumont avenue',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 18,
#     len: 4,
#     end: 22,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '2255 Reisterstown Road',
#     originalLen: 22,
#     subbed: '2255 Reisterstown road',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '900 Argyle Avenue',
#     originalLen: 17,
#     subbed: '900 Argyle avenue',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2718 Fenwick Avenue',
#     originalLen: 19,
#     subbed: '2718 Fenwick avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3248 E Baltimore Street',
#     originalLen: 23,
#     subbed: '3248 E Baltimore street',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4229 Ivanhole Avenue',
#     originalLen: 20,
#     subbed: '4229 Ivanhole avenue',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 17,
#     len: 4,
#     end: 21,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '836 N Woodington Road',
#     originalLen: 21,
#     subbed: '836 N Woodington road',
#     subbedLen: 21 } ]
# [ { found: '',
#     start: 16,
#     len: 0,
#     end: 16,
#     match: [ '(?i)(?=\\bthe alameda)', '\\b' ],
#     replace: null,
#     original: '4033 The Alameda',
#     originalLen: 16,
#     subbed: '4033 The Alameda',
#     subbedLen: 16 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3420 Lyndale Avenue',
#     originalLen: 19,
#     subbed: '3420 Lyndale avenue',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1348 Stonewood Road',
#     originalLen: 19,
#     subbed: '1348 Stonewood road',
#     subbedLen: 19 } ]
# [ { found: 'St',
#     start: 13,
#     len: 2,
#     end: 15,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '525 Rappolla St',
#     originalLen: 15,
#     subbed: '525 Rappolla street',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3402 Dennlyn Road',
#     originalLen: 17,
#     subbed: '3402 Dennlyn road',
#     subbedLen: 17 } ]
# [ { found: 'Ave',
#     start: 18,
#     len: 3,
#     end: 21,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '4101 Park Heights Ave',
#     originalLen: 21,
#     subbed: '4101 Park Heights avenue',
#     subbedLen: 24 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3102 Windsor Avenue',
#     originalLen: 19,
#     subbed: '3102 Windsor avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4716 Amberly Avenue',
#     originalLen: 19,
#     subbed: '4716 Amberly avenue',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 17,
#     len: 4,
#     end: 21,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1526 Northbourne Road',
#     originalLen: 21,
#     subbed: '1526 Northbourne road',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3219 Carlisle Avenue',
#     originalLen: 20,
#     subbed: '3219 Carlisle avenue',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '7306 Harford Road',
#     originalLen: 17,
#     subbed: '7306 Harford road',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3825 Callaway Avenue',
#     originalLen: 20,
#     subbed: '3825 Callaway avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4510 White Avenue',
#     originalLen: 17,
#     subbed: '4510 White avenue',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3808 Sequoia Avenue',
#     originalLen: 19,
#     subbed: '3808 Sequoia avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2213 E Preston Street',
#     originalLen: 21,
#     subbed: '2213 E Preston street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3401 Bateman Avenue',
#     originalLen: 19,
#     subbed: '3401 Bateman avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2256 Linden Avenue',
#     originalLen: 18,
#     subbed: '2256 Linden avenue',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 10,
#     len: 6,
#     end: 16,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1222 Hull Street',
#     originalLen: 16,
#     subbed: '1222 Hull street',
#     subbedLen: 16 } ]
# [ { found: 'Road',
#     start: 12,
#     len: 4,
#     end: 16,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4441 Eldone Road',
#     originalLen: 16,
#     subbed: '4441 Eldone road',
#     subbedLen: 16 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3327 Rueckert Avenue',
#     originalLen: 20,
#     subbed: '3327 Rueckert avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3311 Parklawn Avenue',
#     originalLen: 20,
#     subbed: '3311 Parklawn avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2664 Lauretta Avenue',
#     originalLen: 20,
#     subbed: '2664 Lauretta avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 10,
#     len: 6,
#     end: 16,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3502 Glen Avenue',
#     originalLen: 16,
#     subbed: '3502 Glen avenue',
#     subbedLen: 16 } ]
# [ { found: 'Place',
#     start: 11,
#     len: 5,
#     end: 16,
#     match: '\\bplace\\b',
#     replace: 'place',
#     original: '2225 Eutaw Place Unit 1A 24082856',
#     originalLen: 33,
#     subbed: '2225 Eutaw placeUnit 1A 24082856',
#     subbedLen: 32 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5425 Radecke Avenue',
#     originalLen: 19,
#     subbed: '5425 Radecke avenue',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1913 Chelsea Road',
#     originalLen: 17,
#     subbed: '1913 Chelsea road',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3522 West Caton Avenue',
#     originalLen: 22,
#     subbed: '3522 West Caton avenue',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3116 Ferndale Avenue',
#     originalLen: 20,
#     subbed: '3116 Ferndale avenue',
#     subbedLen: 20 } ]
# [ { found: 'Lane',
#     start: 10,
#     len: 4,
#     end: 14,
#     match: '\\blane\\b',
#     replace: 'lane',
#     original: '4101 Marx Lane',
#     originalLen: 14,
#     subbed: '4101 Marx lane',
#     subbedLen: 14 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1231 Glyndon Avenue',
#     originalLen: 19,
#     subbed: '1231 Glyndon avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3603 Woodbine Avenue',
#     originalLen: 20,
#     subbed: '3603 Woodbine avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '4001 W Franklin Street',
#     originalLen: 22,
#     subbed: '4001 W Franklin street',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5326 Maple Avenue',
#     originalLen: 17,
#     subbed: '5326 Maple avenue',
#     subbedLen: 17 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4201 Fairfax Road',
#     originalLen: 17,
#     subbed: '4201 Fairfax road',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '250 President Street',
#     originalLen: 20,
#     subbed: '250 President street',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3432 West Caton Avenue',
#     originalLen: 22,
#     subbed: '3432 West Caton avenue',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3805 Ravenwood Avenue',
#     originalLen: 21,
#     subbed: '3805 Ravenwood avenue',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2404 Brentwood Avenue',
#     originalLen: 21,
#     subbed: '2404 Brentwood avenue',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2207 Mayfield Avenue',
#     originalLen: 20,
#     subbed: '2207 Mayfield avenue',
#     subbedLen: 20 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '715 Argonne Avenue',
#     originalLen: 18,
#     subbed: '715 Argonne avenue',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '6317 Falkirk Road',
#     originalLen: 17,
#     subbed: '6317 Falkirk road',
#     subbedLen: 17 } ]
# [ { found: 'Blvd',
#     start: 16,
#     len: 4,
#     end: 20,
#     match: '\\bblvd\\b',
#     replace: 'boulevard',
#     original: '5906 Loch Raven Blvd',
#     originalLen: 20,
#     subbed: '5906 Loch Raven boulevard',
#     subbedLen: 25 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1427 Kenhill Avenue',
#     originalLen: 19,
#     subbed: '1427 Kenhill avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1101 Saint Paul Street Unit 711 17211074',
#     originalLen: 40,
#     subbed: '1101 Saint Paul streetUnit 711 17211074',
#     subbedLen: 39 } ]
# [ { found: 'Avenue',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '7111 Park Heights Avenue Unit 204 And Parking Space P3 8833691',
#     originalLen: 62,
#     subbed: '7111 Park Heights avenueUnit 204 And Parking Space P3 8833691',
#     subbedLen: 61 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4209 Moravia Road',
#     originalLen: 17,
#     subbed: '4209 Moravia road',
#     subbedLen: 17 } ]
# [ { found: 'Ave',
#     start: 13,
#     len: 3,
#     end: 16,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '4007 Norfolk Ave',
#     originalLen: 16,
#     subbed: '4007 Norfolk avenue',
#     subbedLen: 19 } ]
# [ { found: 'St',
#     start: 14,
#     len: 2,
#     end: 16,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '2629 N Howard St',
#     originalLen: 16,
#     subbed: '2629 N Howard street',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2538 West Franklin Street',
#     originalLen: 25,
#     subbed: '2538 West Franklin street',
#     subbedLen: 25 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '327 Whitridge Avenue',
#     originalLen: 20,
#     subbed: '327 Whitridge avenue',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 14,
#     len: 4,
#     end: 18,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '1033 Stamford Road',
#     originalLen: 18,
#     subbed: '1033 Stamford road',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 18,
#     len: 4,
#     end: 22,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3613 Reisterstown Road',
#     originalLen: 22,
#     subbed: '3613 Reisterstown road',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '40 South Monastery Avenue',
#     originalLen: 25,
#     subbed: '40 South Monastery avenue',
#     subbedLen: 25 } ]
# [ { found: '',
#     start: 16,
# ...
#     originalLen: 19,
#     subbed: '449 Grindall street',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1170 Nanticoke Street',
#     originalLen: 21,
#     subbed: '1170 Nanticoke street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3303 Elmley Avenue',
#     originalLen: 18,
#     subbed: '3303 Elmley avenue',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1625 McHenry Street',
#     originalLen: 19,
#     subbed: '1625 McHenry street',
#     subbedLen: 19 } ]
# [ { found: 'Road',
#     start: 19,
#     len: 4,
#     end: 23,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4164 Crest Heights Road',
#     originalLen: 23,
#     subbed: '4164 Crest Heights road',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2432 Shirley Avenue',
#     originalLen: 19,
#     subbed: '2432 Shirley avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1036 Hollins Street',
#     originalLen: 19,
#     subbed: '1036 Hollins street',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4503 Luerssen Avenue',
#     originalLen: 20,
#     subbed: '4503 Luerssen avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '610 E 43rd Street',
#     originalLen: 17,
#     subbed: '610 E 43rd street',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1810 Spence Street',
#     originalLen: 18,
#     subbed: '1810 Spence street',
#     subbedLen: 18 } ]
# [ { found: 'Street',
#     start: 19,
#     len: 6,
#     end: 25,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '4008 West Franklin Street',
#     originalLen: 25,
#     subbed: '4008 West Franklin street',
#     subbedLen: 25 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3819 Yolando Road',
#     originalLen: 17,
#     subbed: '3819 Yolando road',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1607 North Rosedale Street',
#     originalLen: 26,
#     subbed: '1607 North Rosedale street',
#     subbedLen: 26 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3128 Presstman Street',
#     originalLen: 21,
#     subbed: '3128 Presstman street',
#     subbedLen: 21 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1642 N Gilmore Street',
#     originalLen: 21,
#     subbed: '1642 N Gilmore street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2012 E North Avenue',
#     originalLen: 19,
#     subbed: '2012 E North avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1500 Lexington Street',
#     originalLen: 21,
#     subbed: '1500 Lexington street',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2702 Greenmount Avenue',
#     originalLen: 22,
#     subbed: '2702 Greenmount avenue',
#     subbedLen: 22 } ]
# [ { found: 'Avenue',
#     start: 10,
#     len: 6,
#     end: 16,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '625 Cator Avenue',
#     originalLen: 16,
#     subbed: '625 Cator avenue',
#     subbedLen: 16 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '4701 Wakefield Road',
#     originalLen: 19,
#     subbed: '4701 Wakefield road',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3215 Chesterfield Avenue',
#     originalLen: 24,
#     subbed: '3215 Chesterfield avenue',
#     subbedLen: 24 } ]
# [ { found: '',
#     start: 16,
#     len: 0,
#     end: 16,
#     match: [ '(?i)(?=\\bthe alameda)', '\\b' ],
#     replace: null,
#     original: '4155 The Alameda Baltimore',
#     originalLen: 26,
#     subbed: '4155 The Alameda Baltimore',
#     subbedLen: 26 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2211 Walshire Avenue',
#     originalLen: 20,
#     subbed: '2211 Walshire avenue',
#     subbedLen: 20 } ]
# [ { found: 'Ave',
#     start: 15,
#     len: 3,
#     end: 18,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '3017 Frederick Ave',
#     originalLen: 18,
#     subbed: '3017 Frederick avenue',
#     subbedLen: 21 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1500 W Lexington Street',
#     originalLen: 23,
#     subbed: '1500 W Lexington street',
#     subbedLen: 23 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2238 W Lexington Street',
#     originalLen: 23,
#     subbed: '2238 W Lexington street',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2535 Cecil Avenue',
#     originalLen: 17,
#     subbed: '2535 Cecil avenue',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 16,
#     len: 6,
#     end: 22,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2702 Greenmount Avenue',
#     originalLen: 22,
#     subbed: '2702 Greenmount avenue',
#     subbedLen: 22 } ]
# [ { found: 'St',
#     start: 13,
#     len: 2,
#     end: 15,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '709 Asburton St',
#     originalLen: 15,
#     subbed: '709 Asburton street',
#     subbedLen: 19 } ]
# [ { found: 'St',
#     start: 17,
#     len: 2,
#     end: 19,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '2238 W Lexington St',
#     originalLen: 19,
#     subbed: '2238 W Lexington street',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5502 Belle Avenue',
#     originalLen: 17,
#     subbed: '5502 Belle avenue',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '6207 Fair Oaks Avenue',
#     originalLen: 21,
#     subbed: '6207 Fair Oaks avenue',
#     subbedLen: 21 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5920 Theodore Avenue',
#     originalLen: 20,
#     subbed: '5920 Theodore avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '675 South President Street',
#     originalLen: 26,
#     subbed: '675 South President street',
#     subbedLen: 26 } ]
# [ { found: '',
#     start: 16,
#     len: 0,
#     end: 16,
#     match: [ '(?i)(?=\\bthe alameda)', '\\b' ],
#     replace: null,
#     original: '4130 The Alameda',
#     originalLen: 16,
#     subbed: '4130 The Alameda',
#     subbedLen: 16 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2202 Penrose Avenue',
#     originalLen: 19,
#     subbed: '2202 Penrose avenue',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1512 East Biddle Street',
#     originalLen: 23,
#     subbed: '1512 East Biddle street',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '5009 Frederick Avenue',
#     originalLen: 21,
#     subbed: '5009 Frederick avenue',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 12,
#     len: 4,
#     end: 16,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '739 Bethnal Road',
#     originalLen: 16,
#     subbed: '739 Bethnal road',
#     subbedLen: 16 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1730 East 32nd Street',
#     originalLen: 21,
#     subbed: '1730 East 32nd street',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 11,
#     len: 4,
#     end: 15,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3105 Taney Road',
#     originalLen: 15,
#     subbed: '3105 Taney road',
#     subbedLen: 15 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3333 Belle Avenue',
#     originalLen: 17,
#     subbed: '3333 Belle avenue',
#     subbedLen: 17 } ]
# [ { found: 'Street',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '307 Lyndhurst Street',
#     originalLen: 20,
#     subbed: '307 Lyndhurst street',
#     subbedLen: 20 } ]
# [ { found: 'Ln',
#     start: 12,
#     len: 2,
#     end: 14,
#     match: '\\bln\\b',
#     replace: 'lane',
#     original: '3913 Brehms Ln',
#     originalLen: 14,
#     subbed: '3913 Brehms lane',
#     subbedLen: 16 } ]
# [ { found: 'Avenue',
#     start: 18,
#     len: 6,
#     end: 24,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4109 Saint Thomas Avenue',
#     originalLen: 24,
#     subbed: '4109 Saint Thomas avenue',
#     subbedLen: 24 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1224 Gilmor Street',
#     originalLen: 18,
#     subbed: '1224 Gilmor street',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2403 Brohawn Avenue',
#     originalLen: 19,
#     subbed: '2403 Brohawn avenue',
#     subbedLen: 19 } ]
# [ { found: 'Avenue',
#     start: 11,
#     len: 6,
#     end: 17,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2802 Riggs Avenue',
#     originalLen: 17,
#     subbed: '2802 Riggs avenue',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3647 Glengyle Avenue Unit 3B Baltimore MD 2121511276396',
#     originalLen: 55,
#     subbed: '3647 Glengyle avenueUnit 3B Baltimore MD 2121511276396',
#     subbedLen: 54 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '2802 Clearview Avenue',
#     originalLen: 21,
#     subbed: '2802 Clearview avenue',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 12,
#     len: 4,
#     end: 16,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '403 Colleen Road',
#     originalLen: 16,
#     subbed: '403 Colleen road',
#     subbedLen: 16 } ]
# [ { found: 'Road',
#     start: 12,
#     len: 4,
#     end: 16,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '5503 Whitby Road',
#     originalLen: 16,
#     subbed: '5503 Whitby road',
#     subbedLen: 16 } ]
# [ { found: 'Street',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2519 E Madison Street',
#     originalLen: 21,
#     subbed: '2519 E Madison street',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 11,
#     len: 4,
#     end: 15,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '2717 Tabot Road',
#     originalLen: 15,
#     subbed: '2717 Tabot road',
#     subbedLen: 15 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '2030 Maisel Street',
#     originalLen: 18,
#     subbed: '2030 Maisel street',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4345 Shamrock Avenue',
#     originalLen: 20,
#     subbed: '4345 Shamrock avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 13,
#     len: 6,
#     end: 19,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '24 East 25th Street',
#     originalLen: 19,
#     subbed: '24 East 25th street',
#     subbedLen: 19 } ]
# [ { found: 'Street',
#     start: 20,
#     len: 6,
#     end: 26,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1617 North Rosedale Street',
#     originalLen: 26,
#     subbed: '1617 North Rosedale street',
#     subbedLen: 26 } ]
# [ { found: 'Street',
#     start: 9,
#     len: 6,
#     end: 15,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '3805 9Th Street',
#     originalLen: 15,
#     subbed: '3805 9Th street',
#     subbedLen: 15 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '6542 Riverview Avenue',
#     originalLen: 21,
#     subbed: '6542 Riverview avenue',
#     subbedLen: 21 } ]
# [ { found: 'Street',
#     start: 17,
#     len: 6,
#     end: 23,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '1828 W Baltimore Street',
#     originalLen: 23,
#     subbed: '1828 W Baltimore street',
#     subbedLen: 23 } ]
# [ { found: 'Avenue',
#     start: 23,
#     len: 6,
#     end: 29,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '1914 North Forest Park Avenue',
#     originalLen: 29,
#     subbed: '1914 North Forest Park avenue',
#     subbedLen: 29 } ]
# [ { found: 'St',
#     start: 11,
#     len: 2,
#     end: 13,
#     match: '\\bst\\b',
#     replace: 'street',
#     original: '708 George St',
#     originalLen: 13,
#     subbed: '708 George street',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 14,
#     len: 6,
#     end: 20,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '601 N Linwood Avenue',
#     originalLen: 20,
#     subbed: '601 N Linwood avenue',
#     subbedLen: 20 } ]
# [ { found: 'Street',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bstreet\\b',
#     replace: 'street',
#     original: '33 N Culver Street',
#     originalLen: 18,
#     subbed: '33 N Culver street',
#     subbedLen: 18 } ]
# [ { found: 'Avenue',
#     start: 15,
#     len: 6,
#     end: 21,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '3908 Frankford Avenue',
#     originalLen: 21,
#     subbed: '3908 Frankford avenue',
#     subbedLen: 21 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3400 Dennlyn Road',
#     originalLen: 17,
#     subbed: '3400 Dennlyn road',
#     subbedLen: 17 } ]
# [ { found: 'Avenue',
#     start: 12,
#     len: 6,
#     end: 18,
#     match: '\\bavenue\\b',
#     replace: 'avenue',
#     original: '4405 Furley Avenue',
#     originalLen: 18,
#     subbed: '4405 Furley avenue',
#     subbedLen: 18 } ]
# [ { found: 'Road',
#     start: 15,
#     len: 4,
#     end: 19,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '3670 Clarenell Road',
#     originalLen: 19,
#     subbed: '3670 Clarenell road',
#     subbedLen: 19 } ]
# [ { found: 'Ave',
#     start: 14,
#     len: 3,
#     end: 17,
#     match: '\\bave\\b',
#     replace: 'avenue',
#     original: '3 N Monastery Ave',
#     originalLen: 17,
#     subbed: '3 N Monastery avenue',
#     subbedLen: 20 } ]
# [ { found: 'Road',
#     start: 13,
#     len: 4,
#     end: 17,
#     match: '\\broad\\b',
#     replace: 'road',
#     original: '907 Stamford Road',
#     originalLen: 17,
#     subbed: '907 Stamford road',
#     subbedLen: 17 } ]
# DONE

# %% [markdown]
# ## Main

# %%
"""main

The main executable script for Close Crawl. This file manages types, flags
and constraints for the case type, year and output data file.

Usage:
    $ python main.py <case_type> <case_year> <path/of/new/dataset>
      <opt: lower_bound> <opt: upper_bound> <opt: debug>

Example usage:
    $ python main.py O 2015 test_set.csv -l=300 -u=600 -d=1

"""
# Out:
# 'main\n\nThe main executable script for Close Crawl. This file manages types, flags\nand constraints for the case type, year and output data file.\n\nUsage:\n    $ python main.py <case_type> <case_year> <path/of/new/dataset>\n      <opt: lower_bound> <opt: upper_bound> <opt: debug>\n\nExample usage:\n    $ python main.py O 2015 test_set.csv -l=300 -u=600 -d=1\n\n'

# %%
from __future__ import absolute_import, print_function, unicode_literals
from json import dump, dumps, load
from os import path, remove, walk
from shutil import rmtree
from time import time

from cleaner import Cleaner
from miner import Miner
from settings import CHECKPOINT, HTML_DIR
from spider import Spider

# %%
def close_crawl(case_type, case_year, output, cases='', lower_bound=0,
                upper_bound=0, debug=False, scrape=True, mine=True,
                clean=True):
    """Main function for Close Crawl.

    Args:
        case_type (`str`): type of foreclosure case, options are 'O' and 'C'
        case_year (`str`): year of foreclosure cases
        output (`str`): path of the output CSV file, along with the valid
            extension (.csv)
        lower_bound (`int`, optional): lower bound of range of cases
        upper_bound (`int`, optional): upper bound of range of cases
        debug (`bool`, optional): option for switching between debug mode.
            Default -> True

    Returns:
        None
    """

    temp_output = "temp_data.csv"
    wait = 0
    case_list = []
    
    print('checkpoint')
    if not path.isfile(CHECKPOINT):
        print("Initializing project...")
        with open(CHECKPOINT, "w") as checkpoint:
            dump(
                {
                    "last_case": "{:04d}".format(int(str(lower_bound)[-4:])),
                    "type": case_type,
                    "year": case_year[-2:],
                    "error_case": '',
                },
                checkpoint
            )

    print('cases')
    if not cases:

        with open(CHECKPOINT) as checkpoint:
            prev_bound = int(load(checkpoint)["last_case"])
            if not lower_bound:
                lower_bound = prev_bound
            upper_bound = upper_bound if int(upper_bound) > int(lower_bound) \
                else str(lower_bound + 5)

        case_list = range(int(lower_bound), int(upper_bound) + 1)

    else:

        with open(cases) as manual_cases:
            case_list = sorted(list(set(load(manual_cases))))

    print('scrape')
    if scrape:
        spider = Spider(
            case_type=case_type, year=case_year[-2:],
            bounds=case_list, gui=False
        )

        spider.save_response()

        wait = spider.WAITING_TIME

    file_array = [filenames for (dirpath, dirnames, filenames)
                  in walk(HTML_DIR)][0]

    start_mine = time()
    print('mine')
    if mine:
        miner = Miner(file_array, temp_output)
        miner.scan_files()
        miner.export()


    print('clean')
    if clean:
        df_obj = Cleaner(temp_output)

        df_obj.init_clean()
        df_obj.download(output)

    print('save')
    with open(CHECKPOINT, "r+") as checkpoint:
        checkpoint_data = load(checkpoint)
        checkpoint_data["last_case"] = sorted(file_array)[-1].split('.')[0][-4:]
        checkpoint.seek(0)
        checkpoint.write(dumps(checkpoint_data))
        checkpoint.truncate()


    print("Crawling runtime: {0:.2f} s".format((end_crawl - start_crawl)))
    print(
        "Downloading runtime: {0:.2f} s".format(
            ((end_crawl - start_crawl) - wait))
    )
    print("Mining runtime: {0:.2f} s".format((end_mine - start_mine)))
    print("Program runtime: {0:.2f} s".format((end - start)))
    print("------------ SCRAPING COMPLETED ------------")

# %%
args = {'type': 'C', 'year': '2014', 'output': 'outputfile.csv', 'file': '', 'lower': '1000', 'upper': '2000', 'debug': '0', 'scrape': True, 'mine': True, 'clean': True}
close_crawl(
    case_type=args["type"], case_year=args["year"], output=args["output"],
    cases=args["file"], lower_bound=args["lower"],
    upper_bound=args["upper"], debug=args["debug"],
    scrape=args["scrape"], mine=args["mine"],
    clean=args["clean"]
)

# %% [markdown]
# ## CLI

# %%
ls
# Out:
#  checkpoint.json      foreclosures_2018_closecrawl.csv   __pycache__/
#  cliargs.py           modules/                           responses/
#  cli.py               no_case.json                       temp_data.csv
# 'Close Crawl.ipynb'   output.csv                         _version.py

# %%
cd ../
# Out:
# /gdrive/My Drive/colabs/vitalSigns/close_crawl

# %%
! python cliargs.py -l=0 -u=9999 -d -s -m C 2018 output.csv
# Out:
# ] [-d] [-s] [-m] [-c]
#                   {O,C} year output
#
# The command line interface for Close Crawl
#
# Parameters:
# | Type of foreclosure cases
# | Year of foreclosure cases
# | Path of output file
#
# Optional parameters:
# | Show this help message and exit
# | Show program's version number and exit
#   | Lower bound of range of cases
#   | Upper bound of range of cases
#    | Path of JSON array of cases
# | Debug mode
# | Scrape only
# | Mine only
# | Clean only
#
# Select a range or a file of cases (but not both).

# %%
ls
# Out:
#  checkpoint.json      foreclosures_2018_closecrawl.csv   __pycache__/
#  cliargs.py           modules/                           responses/
#  cli.py               no_case.json                       temp_data.csv
# 'Close Crawl.ipynb'   output.csv                         _version.py

# %%
"""cliargs

The main command line script for Close Crawl. This file manages types, flags
and constraints for the case type, year and output data file as well as the
processing options.

Parameters:
  {O,C}        | Type of foreclosure cases
  year         | Year of foreclosure cases
  output       | Path of output file

Optional parameters:
  -h, --help   | Show this help message and exit
  -v, --version| Show program's version number and exit
  -l, --lower  | Lower bound of range of cases
  -u, --upper  | Upper bound of range of cases
  -f, --file   | Path of JSON array of cases
  -d, --debug  | Debug mode
  -s, --scrape | Scrape only
  -m, --mine   | Mine only
  -c, --clean  | Clean only

Usage:
    $ python cliarg.py [-h] [-v] [-l] [-u] [-f] [-d] [-s] [-m] [-c]
                  {O,C} year output

Example usages:
    $ python cliarg.py -l=50 -u=3500 -d -s -m C 2016 output.csv
    $ python cliarg.py -c="cases_to_scrape.json" -d O 2014 output01.csv
"""
# Out:
# 'cliargs\n\nThe main command line script for Close Crawl. This file manages types, flags\nand constraints for the case type, year and output data file as well as the\nprocessing options.\n\nParameters:\n  {O,C}        | Type of foreclosure cases\n  year         | Year of foreclosure cases\n  output       | Path of output file\n\nOptional parameters:\n  -h, --help   | Show this help message and exit\n  -v, --version| Show program\'s version number and exit\n  -l, --lower  | Lower bound of range of cases\n  -u, --upper  | Upper bound of range of cases\n  -f, --file   | Path of JSON array of cases\n  -d, --debug  | Debug mode\n  -s, --scrape | Scrape only\n  -m, --mine   | Mine only\n  -c, --clean  | Clean only\n\nUsage:\n    $ python cliarg.py [-h] [-v] [-l] [-u] [-f] [-d] [-s] [-m] [-c]\n                  {O,C} year output\n\nExample usages:\n    $ python cliarg.py -l=50 -u=3500 -d -s -m C 2016 output.csv\n    $ python cliarg.py -c="cases_to_scrape.json" -d O 2014 output01.csv\n'

# %%
from __future__ import absolute_import, print_function, unicode_literals
import sys
from textwrap import dedent

from modules import main

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

if __name__ == "__main__":

    args = {}

    args["type"] = input("Enter type of case (1 char: {C, O}): ")
    args["year"] = input("Enter year of case (4 digit int): ")
    args["output"] = input("Enter name of output file (CSV file path): ")

    opt = int(input("Enter 0 for manual parameters or 1 for automatic: "))
    if bool(opt):
        args["file"] = input("Enter name of cases file (JSON file path): ")
        args["lower"] = args["upper"] = 0

    else:
        args["file"] = ""
        args["lower"] = input("Enter lower bound of cases (1-4 digit int): ")
        args["upper"] = input("Enter upper bound of cases (1-4 digit int): ")

    args["debug"] = input(
        "Enter 0 for default mode, 1 for debug (1 digit int): "
    )

    print(
        dedent(
            """Processing options:\n\n"""
            """For the following options, enter 0 to disable or 1 to enable."""
            """\nNOTE: The script will exit if all but the mining step is """
            """enabled - data cannot be cleaned without being mined first."""
        )
    )

    args["scrape"] = bool(input("Scrape: {0, 1}: "))
    args["mine"] = bool(input("Mine: {0, 1}: "))
    args["clean"] = bool(input("Clean: {0, 1}: "))

    # exit script if all but the mining step is enabled
    if (args["scrape"] and not(args["mine"]) and args["clean"]):
        sys.exit("\nData cannot be cleaned without being mined first.")

    print (args)
    main.close_crawl(
        case_type=args["type"], case_year=args["year"], output=args["output"],
        cases=args["file"], lower_bound=args["lower"],
        upper_bound=args["upper"], debug=args["debug"],
        scrape=args["scrape"], mine=args["mine"],
        clean=args["clean"]
    )

# %% [markdown]
# # Test

# %%
ls
# Out:
#  checkpoint.json  'Close Crawl.ipynb'   __pycache__/
#  cliargs.py        modules/             responses/
#  cli.py            no_case.json         _version.py

# %%
! python cliargs.py -h
# Out:
# ] [-d] [-s] [-m] [-c]
#                   {O,C} year output
#
# The command line interface for Close Crawl
#
# Parameters:
# | Type of foreclosure cases
# | Year of foreclosure cases
# | Path of output file
#
# Optional parameters:
# | Show this help message and exit
# | Show program's version number and exit
#   | Lower bound of range of cases
#   | Upper bound of range of cases
#    | Path of JSON array of cases
# | Debug mode
# | Scrape only
# | Mine only
# | Clean only

# %%
! python cliargs.py O 2018 output.csv -s -l=0000 -u=9999
# Out:
# ] [-d] [-s] [-m] [-c]
#                   {O,C} year output
#
# The command line interface for Close Crawl
#
# Parameters:
# | Type of foreclosure cases
# | Year of foreclosure cases
# | Path of output file
#
# Optional parameters:
# | Show this help message and exit
# | Show program's version number and exit
#   | Lower bound of range of cases
#   | Upper bound of range of cases
#    | Path of JSON array of cases
# | Debug mode
# | Scrape only
# | Mine only
# | Clean only
#
# Select a range or a file of cases (but not both).

# %%
! python cliargs.py -l=0000 -u=9999 -c -s -d -m O 2018 output.csv
# Out:
# ] [-d] [-s] [-m] [-c]
#                   {O,C} year output
#
# The command line interface for Close Crawl
#
# Parameters:
# | Type of foreclosure cases
# | Year of foreclosure cases
# | Path of output file
#
# Optional parameters:
# | Show this help message and exit
# | Show program's version number and exit
#   | Lower bound of range of cases
#   | Upper bound of range of cases
#    | Path of JSON array of cases
# | Debug mode
# | Scrape only
# | Mine only
# | Clean only
#
# Select a range or a file of cases (but not both).
